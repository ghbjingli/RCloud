# %%
# %load_ext rpy2.ipython

# %% [markdown]
# # Test proposed new content for data science CELL program
# # use tidyverse for data cleaning

# %% [markdown]
# ```{r}
# data = c(1,2,2,3,1,2,3,3,1,2,3,3,1)
# fdata = factor(data)
# fdata
#
# rdata = factor(data,labels=c("I","II","III"))
# rdata
#
# levels(fdata) = c('I','II','III')
# fdata
# ```

# %% [markdown]
# ```{r}
# mons = c("March","April","January","November","January",
# "September","October","September","November","August",
# "January","November","November","February","May","August",
# "July","December","August","August","September","November",
# "February","April")
# mons = factor(mons)
# table(mons)

# %% [markdown]
# ```{r}
# mons = factor(mons,levels=c("January","February","March",
#                "April","May","June","July","August","September",
#                "October","November","December"),ordered=TRUE)
# mons[1] < mons[2]
#
# table(mons)

# %% [markdown]
# ```{r}
# mons = factor(mons,levels=c("January","February","March",
#                "April","May","June","July","August","September",
#                "October","November","December"),ordered=TRUE)
# mons[1] < mons[2]
#
# table(mons)

# %% [markdown]
# #### Loading pima.csv
# #### Code
# ```{R}
# pima <- read.csv(rcloud.home("PimaT.csv", user="jl2408"))
# ```
#
# #### Create a summary and str of the dataset
# #### Code
# ```{R}
# summary(pima)
# str(pima)
# ```

# %%
# %%R
# library(tidyverse)

# %%
# %%R
# mtcars <- read_csv(readr_example("mtcars.csv"))

# %%
# %%R
# data()

# %%
# %%R
# # data(package = .packages(all.available = TRUE))

# %%
# %%R
# library(dplyr)
# starwars %>%
#   filter(species == "Droid")

# %%
# %%R
# starwars %>%
#   select(name, ends_with("color"))

# %%
# %%R
# starwars %>%
#   mutate(bmi = mass / ((height / 100)  ^ 2)) %>% select(name:mass, bmi)

# %%
# %%R
# starwars %>%
#   arrange(desc(mass))

# %%
# %%R
# starwars %>%
#   group_by(species) %>%
#   summarise(
#     n = n(),
#     mass = mean(mass, na.rm = TRUE)
#   ) %>%
#   filter(n > 1)

# %%
# %%R
# library(tidyr)

# %%
# %%R
# stocks <- data_frame(
#   time = as.Date('2009-01-01') + 0:9,
#   X = rnorm(10, 0, 1),
#   Y = rnorm(10, 0, 2),
#   Z = rnorm(10, 0, 4)
# )

# %%
# %%R
# stocks

# %%
# %%R
# gather(stocks, stock, price, -time)

# %%
# %%R
# stocks %>% gather(stock, price, -time)

# %%
# %%R
# stocks %>% gather(stock, price, -time) %>% spread(stock, price)

# %%
# %%R
# mini_iris <- iris[c(1, 51, 101), ]

# %%
# %%R
# mini_iris

# %%
# %%R
# gather(mini_iris, key = flower_att, value = measurement,
#        Sepal.Length, Sepal.Width, Petal.Length, Petal.Width)

# %%
# %%R
# gather(mini_iris, key = flower_att, value = measurement, -Species)

# %%
# %%R
# mini_iris <-
#   iris %>%
#   group_by(Species) %>%
#   slice(1)

# %%
# %%R
# mini_iris

# %%
# %%R
# mini_iris %>% gather(key = flower_att, value = measurement, -Species)

# %%
# %%R
# df <- data.frame(x = c("a", "b"), y = c(3, 4), z = c(5, 6))

# %%
# %%R
# df

# %%
# %%R
# class(c("a","b"))

# %%
# %%R
# is.vector(1:10)

# %%
# %%R
# library(purrr)
# 1:10 %>%
#   map(rnorm, n = 10)

# %%
# %%R
# xx <- c(1.7, "a")

# %%
# %%R
# xx

# %%
# %%R
# xx <- c(TRUE, 2)

# %%
# %%R
# xx

# %%
# %%R
# xx <- c("a", TRUE)

# %%
# %%R
# xx

# %%
# %%R
# m <- matrix(nrow = 2, ncol = 2)
# m
# dim(m)
# attributes(m)

# %%
# %%R
# m <- matrix(1:6, nrow=2, ncol =3)

# %%
# %%R
# m
# typeof(m)
# class(m)

# %%
# %%R
# x <- 1:3
# y <- 10:12
# cbind(x,y)
# # or
# rbind(x,y)

# %%
# %%R
# x <- list(1, "a", TRUE, 1+4i)
# x
# typeof(x)
# class(x)
# x <- 1:10
# x <- as.list(x)
# x
# typeof(x)
# class(x)
# length(x)

# %%
# %%R
# x[1]
# x[2]
# typeof(x[1])
# class(x[1])

# %%
# %%R
# x[[1]]
# x[[2]]
# typeof(x[[1]])
# class(x[[1]])

# %%
# %%R
# xlist <- list(a = "Rich FitzJohn", b = 1:10, data = head(iris))

# %%
# %%R
# xlist[1]
# xlist[[1]]
# xlist$a
# xlist[[2]]
# xlist$b[1]
# xlist$b[5]
# xlist$data
# xlist$data[1,]

# %%
# %%R
# x <- factor(c("yes", "no", "no", "yes", "yes"))
# x
#
# table(x)
#
# unclass(x)

# %%
# %%R
# data = c(1,2,2,3,1,2,3,3,1,2,3,3,1)
# fdata = factor(data)
# levels(fdata) = c('I','II','III')
# fdata
# typeof(fdata)
# class(fdata)
# str(fdata)

# %%
# %%R
# mons = c("March","April","January","November","January",
# "September","October","September","November","August",
# "January","November","November","February","May","August",
# "July","December","August","August","September","November",
# "February","April")
# mons = factor(mons)

# %%
# %%R
# str(mons)

# %%
# %%R
# mons = factor(mons,levels=c("January","February","March",
# "April","May","June","July","August","September",
# "October","November","December"),ordered=TRUE)
# str(mons)
# table(mons)

# %%
# %%R
# x = as.numeric(mons)
# x

# %%
# %%R
# fert = c(10,20,20,50,10,20,10,50,20)
# fert = factor(fert,levels=c(10,20,50),ordered=TRUE)
# fert
# str(fert)
# x = as.numeric(fert)
# x
# levels(fert)
# levels(fert)[fert]
# as.numeric(levels(fert)[fert])

# %%
# %%R
# data <- c(5,19,11,23,12,7,3,21)
# t <- (mean(data) - 10)/(sd(data)/sqrt(length(data)))
# t
# 2*pt(-abs(t),df=7)

# %%
# !hostname -f
# !ls -l

# %%
# %%R
# library(ISwR)
# rmr
# str(rmr)
# fit <- lm(metabolic.rate ~ body.weight, rmr)
# summary(fit)

# %%
import sys
print sys.version

# %%
# !conda env list

# %%
# %%R
# testdata <- rcloud.get.asset("test.csv")
# testdf <- read.csv(textConnection(testdata), header=FALSE)
# testdf
# str(testdf)

# %%
# %%R
# 1+1

# %%
# !hdfs dfs -ls /

# %%
# !hdfs dfsadmin -report

# %%
import numpy as np
a = [1,2,3]
b = [4,5,6]
c = np.meshgrid(a,b)
print c

# %%
#matplotlib.use('Agg')
#import matplotlib
import pylab as plt
import numpy as np
x=np.arange(0,2,0.001)
y=np.sin(x)**2+4*np.cos(x)
fig = plt.figure()
plt.plot(x,y,'r.')

# %%
# !ls /tmp/Rserv/

# %%
# %%R
# rcloud.home()

# %%
# !ls -l /opt/data/share01/jl2408
