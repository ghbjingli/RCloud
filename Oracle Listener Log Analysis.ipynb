# %% [markdown]
# Analyze Oracle listener log. Count number of rows group by Date
# Variables: Date
# use note to copy portion of log files, maybe a few hours to a new file so that size will be small enough
# lsnr_log_03012021_8 - at 8 oclock
# Uplpoad the file to the remote Linux server

# %%
list.files(rcloud.home(), full.names=TRUE)
lsnr_log <- read.csv(rcloud.home("lsnr2_log_03012021_8.csv", user="jl2408"), sep="*", header = T, check.names = F)

# %% [markdown]
# Explore the data
# ```{R}
# str(lsnr_log)
# summary(lsnr_log)

# %% [markdown]
# How many cars are bad buy?
# ```{R}
# data.frame(table(lsnr_log$Date))
